# %% [markdown]
# <a href="https://colab.research.google.com/github/sanfordmalman/My-publications/blob/master/Copy_of_Copy_of_BookNLP_reconstructingEnvGov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demo for running BookNLP on an input text.  To use a GPU in Google Colab, change the following:
#
# `Runtime > Change runtime type > Hardware accelerator > GPU`
#
# To execute this notebook, sign in to Google and then run all cells
#
# `Runtime > Run all`

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import files

uploaded = files.upload()

#for fn in uploaded.keys():
#  print('User uploaded file "{name}" with length {length} bytes'.format(
#      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7eefb01e-3684-47c8-8a81-430850a521b9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eefb01e-3684-47c8-8a81-430850a521b9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving reconstructing environmental governance.txt to reconstructing environmental governance.txt

# %% [markdown]
# # New Section

# %%
# !pip install booknlp
# Out:
# Collecting booknlp
#   Downloading booknlp-1.0.7.tar.gz (2.4 MB)
#      |████████████████████████████████| 2.4 MB 10.1 MB/s
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from booknlp) (1.10.0+cu111)
# Requirement already satisfied: tensorflow>=1.15 in /usr/local/lib/python3.7/dist-packages (from booknlp) (2.8.0)
# Collecting spacy>=3
#   Downloading spacy-3.2.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 49.5 MB/s
# Collecting transformers>=4.11.3
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 61.8 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.21.5)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.10.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.9.0)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.8 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (57.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (4.63.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (2.0.6)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (653 kB)
#      |████████████████████████████████| 653 kB 60.4 MB/s
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 66.6 MB/s
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (21.3)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
#      |████████████████████████████████| 451 kB 50.8 MB/s
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (0.4.1)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 22.2 MB/s
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3->booknlp) (1.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3->booknlp) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3->booknlp) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3->booknlp) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->booknlp) (2021.10.8)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.13.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.24.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.17.3)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (13.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.6.3)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 56.6 MB/s
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.44.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (0.5.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=1.15->booknlp) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=1.15->booknlp) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=1.15->booknlp) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (4.11.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.15->booknlp) (3.2.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 58.6 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 7.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (2019.12.20)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 51.3 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 62.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.11.3->booknlp) (3.6.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3->booknlp) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3->booknlp) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.11.3->booknlp) (1.1.0)
# Building wheels for collected packages: booknlp
#   Building wheel for booknlp (setup.py) ... done
#   Created wheel for booknlp: filename=booknlp-1.0.7-py3-none-any.whl size=2420766 sha256=704787926218b5d88be87d54162d8d396668b0e8bf8b9586f3fc27de30738151
#   Stored in directory: /root/.cache/pip/wheels/3e/79/30/e49074dd91db7434da782e5d48e44bdabe066c07adf465f376
# Successfully built booknlp
# Installing collected packages: catalogue, typer, srsly, pyyaml, pydantic, tokenizers, thinc, tf-estimator-nightly, spacy-loggers, spacy-legacy, sacremoses, pathy, langcodes, huggingface-hub, transformers, spacy, booknlp
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed booknlp-1.0.7 catalogue-2.0.6 huggingface-hub-0.4.0 langcodes-3.3.0 pathy-0.6.1 pydantic-1.8.2 pyyaml-6.0 sacremoses-0.0.49 spacy-3.2.3 spacy-legacy-3.0.9 spacy-loggers-1.0.1 srsly-2.4.2 tf-estimator-nightly-2.8.0.dev2021122109 thinc-8.0.15 tokenizers-0.11.6 transformers-4.17.0 typer-0.4.0

# %%
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 13.0 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.63.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 8.1 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (57.4.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.21.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from booknlp.booknlp import BookNLP

# %%
model_params={
		"pipeline":"entity,quote,supersense,event,coref", 
		"model":"big", 
	}

booknlp=BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# downloading entities_google_bert_uncased_L-6_H-768_A-12-v1.0.model
# downloading coref_google_bert_uncased_L-12_H-768_A-12-v1.0.model
# downloading speaker_google_bert_uncased_L-12_H-768_A-12-v1.0.1.model
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/384 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/258M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# --- startup: 54.298 seconds ---

# %%
inputFile="reconstructing environmental governance.txt"
outputDir="reconstructing environmental governance/"
idd="reconstructing environmental governance"

booknlp.process(inputFile, outputDir, idd)
# Out:
# --- spacy: 52.531 seconds ---
# --- entities: 117.243 seconds ---
# --- quotes: 0.353 seconds ---
# --- attribution: 38.647 seconds ---
# --- name coref: 3.569 seconds ---
# --- coref: 43.463 seconds ---
# --- TOTAL (excl. startup): 256.482 seconds ---, 146824 words

# %%
import json
from collections import Counter

# %%
def proc(filename):
    with open(filename) as file:
        data=json.load(file)
    return data

# %%
data=proc("reconstructing environmental governance/reconstructing environmental governance.book")

# %%
def get_counter_from_dependency_list(dep_list):
    counter=Counter()
    for token in dep_list:
        term=token["w"]
        tokenGlobalIndex=token["i"]
        counter[term]+=1
    return counter

# %%
for character in data["characters"]:
    
    agentList=character["agent"]
    patientList=character["patient"]
    possList=character["poss"]
    modList=character["mod"]
    
    character_id=character["id"]
    count=character["count"]

    referential_gender_distribution=referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]
        
        print(character_id, count, max_proper_mention, referential_gender)

        print()
        printTop=10
        for k, v in get_counter_from_dependency_list(possList).most_common(printTop):
            print("\tposs\t%s %s" % (v,k))
        print()
        for k, v in get_counter_from_dependency_list(agentList).most_common(printTop):
            print("\tagent\t%s %s" % (v,k))        
        print()
        for k, v in get_counter_from_dependency_list(patientList).most_common(printTop):
            print("\tpatient\t%s %s" % (v,k))       
        print()
        for k, v in get_counter_from_dependency_list(modList).most_common(printTop):
            print("\tmod\t%s %s" % (v,k))    
        print()
# Out:
# 520 60 Andrew Ross Sorkin he/him/his
#
# 	poss	1 advice
# 	poss	1 experiences
# 	poss	1 theory
# 	poss	1 experience
# 	poss	1 visits
#
# 	agent	4 asked
# 	agent	3 saw
# 	agent	2 report
# 	agent	2 went
# 	agent	2 pointed
# 	agent	1 notes
# 	agent	1 arrived
# 	agent	1 expected
# 	agent	1 visit
# 	agent	1 going
#
# 	patient	3 told
# 	patient	2 asked
# 	patient	1 invited
# 	patient	1 had
# 	patient	1 invite
# 	patient	1 allowed
# 	patient	1 welcomed
#
# 	mod	1 employee
# 	mod	1 able
# 	mod	1 harmless
# 	mod	1 one
# 	mod	1 amazed
# 	mod	1 lucky
# 	mod	1 safe
# 	mod	1 shocked
#
# 489 42 EPA they/them/their
#
# 	poss	2 Initiative
# 	poss	1 communication
# 	poss	1 ability
# 	poss	1 pamphlet
# 	poss	1 coordinator
# 	poss	1 process
# 	poss	1 Administrator
# 	poss	1 mission
#
# 	agent	2 told
# 	agent	2 had
# 	agent	1 fined
# 	agent	1 turned
# 	agent	1 fostered
# 	agent	1 identified
# 	agent	1 brought
# 	agent	1 order
# 	agent	1 do
# 	agent	1 done
#
# 	patient	1 tell
# 	patient	1 show
# 	patient	1 denounced
#
#
# 531 33 OTA he/him/his
#
# 	poss	1 representations
# 	poss	1 work
# 	poss	1 offers
# 	poss	1 head
# 	poss	1 POTW
# 	poss	1 Gayl
#
# 	agent	3 worked
# 	agent	1 became
# 	agent	1 came
# 	agent	1 told
# 	agent	1 helped
# 	agent	1 visited
# 	agent	1 got
# 	agent	1 received
# 	agent	1 selling
# 	agent	1 had
#
# 	patient	1 call
# 	patient	1 aided
#
#
# 560 33 Dr. David he/him/his
#
# 	poss	1 car
# 	poss	1 basement
# 	poss	1 stint
#
# 	agent	2 had
# 	agent	2 said
# 	agent	2 ask
# 	agent	2 gave
# 	agent	1 estimated
# 	agent	1 read
# 	agent	1 commented
# 	agent	1 got
# 	agent	1 told
# 	agent	1 heard
#
# 	patient	1 told
# 	patient	1 tell
# 	patient	1 thanked
#
#
# 482 32 Congress they/them/their
#
# 	poss	1 process
# 	poss	1 part
#
# 	agent	2 do
# 	agent	1 lowered
# 	agent	1 appropriated
# 	agent	1 made
# 	agent	1 passed
# 	agent	1 need
# 	agent	1 require
# 	agent	1 eliminated
# 	agent	1 cut
# 	agent	1 did
#
#
# 	mod	1 clear
#
# 529 32 DEP they/them/their
#
# 	poss	1 reductions
# 	poss	1 wisdom
# 	poss	1 work
#
# 	agent	1 grew
# 	agent	1 institutionalize
# 	agent	1 told
# 	agent	1 urged
# 	agent	1 did
# 	agent	1 heard
# 	agent	1 agreed
# 	agent	1 wrote
# 	agent	1 knew
# 	agent	1 saw
#
# 	patient	1 commend
# 	patient	1 enabling
#
# 	mod	1 agreeable
# 	mod	1 kind
#
# 780 32 Manfred Bowditch he/him/his
#
# 	poss	1 blogs
#
# 	agent	3 know
# 	agent	2 tell
# 	agent	2 get
# 	agent	1 obscured
# 	agent	1 argued
# 	agent	1 found
# 	agent	1 recall
# 	agent	1 report
# 	agent	1 saw
# 	agent	1 have
#
# 	patient	1 involved
# 	patient	1 protecting
# 	patient	1 told
#
# 	mod	1 participant
# 	mod	1 child
# 	mod	1 grateful
#
# 992 24 Schlichtmann he/him/his
#
# 	poss	1 approach
# 	poss	1 cases
# 	poss	1 case
# 	poss	1 job
#
# 	agent	2 talked
# 	agent	2 said
# 	agent	2 suing
# 	agent	2 represent
# 	agent	1 returned
# 	agent	1 resumed
# 	agent	1 going
# 	agent	1 developed
# 	agent	1 refined
# 	agent	1 establishes
#
# 	patient	1 asked
# 	patient	1 approve
#
# 	mod	1 famous
#
# 473 22 Douglas Fisher he/him/his
#
#
# 	agent	3 had
# 	agent	2 died
# 	agent	2 proceeded
# 	agent	1 see
# 	agent	1 wish
# 	agent	1 know
# 	agent	1 seen
# 	agent	1 visited
# 	agent	1 hear
# 	agent	1 explained
#
# 	patient	2 repeat
# 	patient	1 asked
#
# 	mod	1 sure
#
# 553 22 Surette he/him/his
#
# 	poss	1 company
# 	poss	1 out
#
# 	agent	3 said
# 	agent	2 learned
# 	agent	2 determined
# 	agent	1 came
# 	agent	1 took
# 	agent	1 got
# 	agent	1 letting
# 	agent	1 buying
# 	agent	1 saw
# 	agent	1 had
#
# 	patient	1 inspired
# 	patient	1 asked
#
# 	mod	1 delighted
# 	mod	1 proud
#
# 1002 20 Judge Jed Rakoff he/him/his
#
# 	poss	1 questioner
#
# 	agent	2 find
# 	agent	2 have
# 	agent	2 answer
# 	agent	1 providing
# 	agent	1 responded
# 	agent	1 note
# 	agent	1 recommend
# 	agent	1 having
# 	agent	1 think
# 	agent	1 used
#
# 	patient	1 challenged
# 	patient	1 asked
#
# 	mod	1 able
#
# 506 19 the POTW they/them/their
#
# 	poss	1 permit
#
# 	agent	2 told
# 	agent	1 handle
# 	agent	1 manage
# 	agent	1 passed
# 	agent	1 violating
# 	agent	1 kept
# 	agent	1 changing
# 	agent	1 had
# 	agent	1 turned
# 	agent	1 leaned
#
# 	patient	2 told
# 	patient	1 telling
# 	patient	1 fined
# 	patient	1 create
#
#
# 552 18 Broadbent he/him/his
#
# 	poss	1 story
# 	poss	1 parts
#
# 	agent	2 stopped
# 	agent	2 told
# 	agent	2 did
# 	agent	1 allowed
# 	agent	1 calculated
# 	agent	1 spent
# 	agent	1 plating
# 	agent	1 used
# 	agent	1 needed
# 	agent	1 created
#
# 	patient	1 asked
# 	patient	1 showed
#
# 	mod	1 willing
#
# 456 17 Barbara Kelley she/her
#
# 	poss	1 support
# 	poss	1 guidance
# 	poss	1 wisdom
# 	poss	1 door
#
# 	agent	1 instituted
# 	agent	1 forget
# 	agent	1 described
# 	agent	1 said
# 	agent	1 had
# 	agent	1 got
# 	agent	1 insulting
# 	agent	1 know
# 	agent	1 talking
# 	agent	1 kept
#
# 	patient	1 invited
#
#
# 571 17 George W. Bush he/him/his
#
# 	poss	1 acts
# 	poss	1 administration
# 	poss	1 duty
# 	poss	1 President
#
# 	agent	1 responded
# 	agent	1 downgraded
# 	agent	1 entered
# 	agent	1 announced
# 	agent	1 reaching
# 	agent	1 needed
# 	agent	1 understand
# 	agent	1 believed
#
# 	patient	2 elected
#
#
# 457 16 George Frantz he/him/his
#
# 	poss	1 work
# 	poss	1 friendship
#
# 	agent	2 led
# 	agent	2 moved
# 	agent	1 told
# 	agent	1 came
# 	agent	1 used
# 	agent	1 ran
# 	agent	1 caught
# 	agent	1 overseeing
#
# 	patient	1 thank
# 	patient	1 trusted
# 	patient	1 had
#
#
# 848 14 the Europeans they/them/their
#
# 	poss	1 pigs
# 	poss	1 condition
# 	poss	1 duty
# 	poss	1 energies
# 	poss	1 depredations
#
# 	agent	2 ate
# 	agent	1 treated
# 	agent	1 regarded
# 	agent	1 fenced
# 	agent	1 exercised
# 	agent	1 considered
# 	agent	1 owned
# 	agent	1 let
# 	agent	1 thought
#
#
#
# 862 14 John Locke he/him/his
#
# 	poss	1 Treatise
# 	poss	1 enclosure
# 	poss	1 thirst
# 	poss	1 idea
#
# 	agent	1 notes
# 	agent	1 injured
# 	agent	1 took
# 	agent	1 left
# 	agent	1 pointed
#
# 	patient	1 left
#
# 	mod	1 part
#
# 872 14 Clark he/him/his
#
# 	poss	1 wastewater
# 	poss	1 metals
# 	poss	1 permit
#
# 	agent	2 went
# 	agent	1 told
# 	agent	1 said
# 	agent	1 brought
# 	agent	1 realized
# 	agent	1 learned
# 	agent	1 installed
# 	agent	1 neutralized
# 	agent	1 speak
# 	agent	1 ended
#
# 	patient	1 hired
#
#
# 879 13 John O’Hare he/him/his
#
# 	poss	1 Discharge
# 	poss	1 hands
# 	poss	1 Permits
# 	poss	1 boss
#
# 	agent	2 did
# 	agent	1 issued
# 	agent	1 have
# 	agent	1 told
# 	agent	1 contacted
#
# 	patient	1 told
#
# 	mod	1 sympathetic
#
# 954 13 Schumacher he/him/his
#
# 	poss	1 brother
#
# 	agent	1 worked
# 	agent	1 told
# 	agent	1 called
# 	agent	1 devoted
# 	agent	1 dropped
# 	agent	1 ended
# 	agent	1 says
#
# 	patient	1 host
# 	patient	1 devoted
#
#
# 598 12 EPA they/them/their
#
# 	poss	1 Horse
# 	poss	1 Parker
# 	poss	1 authority
#
# 	agent	2 went
# 	agent	1 promulgated
# 	agent	1 used
# 	agent	1 kept
# 	agent	1 put
# 	agent	1 spent
#
# 	patient	1 turned
#
#
# 718 11 Dupont he/him/his
#
#
# 	agent	1 comes
# 	agent	1 shares
# 	agent	1 knows
# 	agent	1 wants
# 	agent	1 respects
# 	agent	1 innovate
# 	agent	1 come
# 	agent	1 sell
# 	agent	1 demonstrated
# 	agent	1 hid
#
#
#
# 769 11 God he/him/his
#
# 	poss	1 labour
# 	poss	1 own
# 	poss	1 property
#
# 	agent	2 given
# 	agent	1 gave
# 	agent	1 removes
# 	agent	1 left
# 	agent	1 hath
# 	agent	1 have
# 	agent	1 is
#
#
#
# 439 10 Biden he/him/his
#
# 	poss	1 Plan
#
# 	agent	1 opened
# 	agent	1 did
# 	agent	1 make
# 	agent	1 pursuing
# 	agent	1 signed
# 	agent	1 noted
# 	agent	1 doing
# 	agent	1 says
#
#
#
# 496 10 Freud he/him/his
#
# 	poss	1 advice
# 	poss	1 suggestion
#
# 	agent	1 argued
# 	agent	1 spoke
# 	agent	1 suggest
# 	agent	1 noted
# 	agent	1 observed
# 	agent	1 nodded
#
#
# 	mod	1 examples
#
# 545 10 Tim he/him/his
#
#
# 	agent	3 visited
# 	agent	1 walked
# 	agent	1 saw
# 	agent	1 said
# 	agent	1 explained
# 	agent	1 continues
#
# 	patient	1 invited
#
# 	mod	1 employee
#
# 621 10 Thomas Man they/them/their
#
#
# 	agent	1 look
# 	agent	1 come
# 	agent	1 see
# 	agent	1 looking
# 	agent	1 refuse
# 	agent	1 maintain
#
# 	patient	1 tell
#
#
# 733 10 VP Aatish Salvi he/him/his
#
# 	poss	1 reluctance
#
# 	agent	3 said
# 	agent	1 confessed
# 	agent	1 realized
# 	agent	1 agreed
# 	agent	1 supported
#
# 	patient	1 gone
#
#
# 881 10 Printers they/them/their
#
# 	poss	1 efforts
# 	poss	1 viewpoints
#
# 	agent	1 came
# 	agent	1 knew
# 	agent	1 trusted
# 	agent	1 did
# 	agent	1 come
#
# 	patient	1 got
#
#
# 449 9 Rawls he/him/his
#
# 	poss	2 theory
# 	poss	1 contribution
# 	poss	1 vision
# 	poss	1 concept
#
# 	agent	1 provides
# 	agent	1 thinks
#
#
# 	mod	1 philosopher
#
# 547 9 Ronald Reagan he/him/his
#
# 	poss	2 Order
#
# 	agent	2 said
# 	agent	1 helped
# 	agent	1 instituted
# 	agent	1 has
# 	agent	1 wrote
# 	agent	1 like
# 	agent	1 makes
# 	agent	1 get
#
#
#
# 559 9 Michael Dukakis he/him/his
#
# 	poss	1 Commissioner
#
# 	agent	1 paid
# 	agent	1 visit
# 	agent	1 walk
#
# 	patient	1 reached
# 	patient	1 known
#
#
# 606 9 Al Gore he/him/his
#
# 	poss	1 sponsors.281
# 	poss	1 efforts
# 	poss	1 vision
#
# 	agent	1 doing
# 	agent	1 promote
# 	agent	1 has
# 	agent	1 announced
#
#
#
# 497 8 Donald Trump he/him/his
#
# 	poss	1 opposition
#
# 	agent	1 tried
# 	agent	1 used
# 	agent	1 failed
# 	agent	1 reversed
#
# 	patient	1 electing
#
#
# 548 8 Paul Richard he/him/his
#
# 	poss	1 program
# 	poss	1 answers
# 	poss	1 conference
#
# 	agent	1 organized
#
#
#
# 494 7 Henry David Thoreau he/him/his
#
# 	poss	1 time
# 	poss	1 Disobedience
#
# 	agent	1 felt
# 	agent	1 accepted
# 	agent	1 wanted
# 	agent	1 mourning
#
#
#
# 572 7 Gingrich he/him/his
#
# 	poss	1 impact
# 	poss	1 speakership
# 	poss	1 message
#
# 	agent	1 supported
# 	agent	1 running
# 	agent	1 called
#
#
#
# 617 7 Peg Seminario she/her
#
# 	poss	1 view
#
# 	agent	1 spoke
# 	agent	1 demonstrated
# 	agent	1 worked
# 	agent	1 appreciate
# 	agent	1 describes
# 	agent	1 contrasts
# 	agent	1 views
#
#
#
# 666 7 Martha Albertson Fineman she/her
#
# 	poss	1 colleague
#
# 	agent	1 developed
# 	agent	1 talking
#
# 	patient	1 agree
#
#
# 689 7 Peter Kropotkin he/him/his
#
#
# 	agent	1 found
# 	agent	1 are
# 	agent	1 thought
# 	agent	1 ’s
#
#
#
# 710 7 Rylands he/him/his
#
# 	poss	1 property
#
# 	agent	1 built
#
#
# 	mod	1 liable
#
# 878 7 Robbins they/them/their
#
# 	poss	1 story
# 	poss	1 evaporator
#
# 	agent	1 telling
#
# 	patient	1 prosecuting
#
#
# 906 7 Mark he/him/his
#
# 	poss	1 finger
#
# 	agent	2 began
# 	agent	1 asked
# 	agent	1 put
#
# 	patient	1 recognized
#
#
# 1010 7 Daly she/her
#
#
# 	agent	2 said
# 	agent	1 told
# 	agent	1 used
# 	agent	1 attended
#
#
#
# 440 6 Clinton he/him/his
#
# 	poss	1 tightening
# 	poss	1 standards
#
# 	agent	2 did
# 	agent	2 have
# 	agent	1 deemed
#
#
#
# 761 6 Mumford he/him/his
#
#
# 	agent	1 recalls
# 	agent	1 says
# 	agent	1 notes
# 	agent	1 proceeded
# 	agent	1 suppressed
# 	agent	1 points
#
#
# 	mod	1 thinker
#
# 863 6 Paolo he/him/his
#
#
# 	agent	1 continued
# 	agent	1 sent
# 	agent	1 working
# 	agent	1 said
#
#
#
# 868 6 David Good he/him/his
#
# 	poss	2 family
# 	poss	1 mother
#
# 	agent	1 told
#
#
#
# 875 6 Robert Chatel he/him/his
#
# 	poss	1 plating
#
# 	agent	1 told
# 	agent	1 use
# 	agent	1 said
#
# 	patient	1 interviewed
#
#
# 455 5 Brown he/him/his
#
#
# 	agent	1 went
# 	agent	1 reasoned
#
#
#
# 490 5 Obama she/her
#
#
# 	agent	1 vetoed
# 	agent	1 put
#
#
#
# 507 5 POTWs they/them/their
#
#
# 	agent	1 handle
# 	agent	1 receive
# 	agent	1 discharging
# 	agent	1 used
#
#
#
# 569 5 Romm he/him/his
#
#
# 	agent	1 terms
# 	agent	1 wrote
# 	agent	1 noted
# 	agent	1 concluded
#
#
# 	mod	1 founder
#
# 628 5 Blake Emerson he/him/his
#
# 	poss	1 vision
#
# 	agent	1 traces
# 	agent	1 wrote
#
#
#
# 646 5 Albert Einstein he/him/his
#
#
# 	agent	1 signed
# 	agent	1 wrote
# 	agent	1 opined
#
#
# 	mod	1 examples
#
# 686 5 Adam Smith he/him/his
#
#
# 	agent	1 believed
# 	agent	1 wrote
# 	agent	1 agreeing
#
# 	patient	1 hailed
#
#
# 693 5 James Madison he/him/his
#
#
# 	agent	1 theorized
# 	agent	1 made
# 	agent	1 learned
#
#
#
# 766 5 Davies they/them/their
#
#
# 	agent	1 envisions
# 	agent	1 writes
# 	agent	1 suggests
# 	agent	1 improving
#
#
#
# 858 5 George Catlin he/him/his
#
#
# 	agent	1 visited.357
# 	agent	1 proposed
# 	agent	1 witnessed
#
#
# 	mod	1 lawyer
#
# 893 5 Dwight Peavey he/him/his
#
# 	poss	1 knowledge
#
# 	agent	1 ask
# 	agent	1 answer
# 	agent	1 retired
# 	agent	1 went
#
# 	patient	1 call
#
#
# 898 5 Ann Lowry they/them/their
#
# 	poss	1 selves
#
# 	agent	1 done
#
# 	patient	1 mold
# 	patient	1 caught
#
#
# 904 5 Howie Carr he/him/his
#
# 	poss	1 cynicism
#
# 	agent	1 stood
# 	agent	1 wrote
# 	agent	1 saw
#
# 	patient	1 harming
#
#
# 945 5 Borlaug he/him/his
#
# 	poss	1 years
#
# 	agent	1 headed
# 	agent	1 intended
#
#
# 	mod	1 committed
#
# 961 5 Lewis Mumford he/him/his
#
#
# 	agent	1 described
# 	agent	1 points
# 	agent	1 is
# 	agent	1 insisted
# 	agent	1 says
#
#
#
# 979 5 the Russians they/them/their
#
#
# 	agent	1 knew
# 	agent	1 refused
# 	agent	1 done
# 	agent	1 developed
# 	agent	1 had
#
#
#
# 476 4 Indigenous Peoples they/them/their
#
#
# 	agent	1 choose
# 	agent	1 give
#
# 	patient	1 engaged
#
#
# 499 4 Leonardo Da Vinci he/him/his
#
# 	poss	1 mind
# 	poss	1 life
#
# 	agent	1 hold
#
# 	patient	1 observes
#
#
# 556 4 Companies they/them/their
#
#
# 	agent	1 reported
# 	agent	1 said
#
# 	patient	1 cost
#
#
# 593 4 Democrats they/them/their
#
# 	poss	1 patriotism
#
#
# 	patient	1 casting
#
#
# 596 4 OSHA he/him/his
#
#
# 	agent	1 enforce
#
# 	patient	1 hobbled
#
#
# 633 4 The Bushes they/them/their
#
#
# 	agent	1 said
# 	agent	1 balancing
# 	agent	1 drinking
#
#
# 	mod	1 deliverers
#
# 634 4 Dick Cheney he/him/his
#
# 	poss	1 Force
# 	poss	1 meetings
#
#
#
# 	mod	1 president
#
# 644 4 Shermer they/them/their
#
#
# 	agent	1 writes
# 	agent	1 quotes
# 	agent	1 lack
#
#
# 	mod	1 publisher
#
# 681 4 Vaclav Havel he/him/his
#
# 	poss	1 words
#
# 	agent	1 said
#
#
# 	mod	1 first
# 	mod	1 right
#
# 691 4 Holmes he/him/his
#
#
# 	agent	2 wrote
# 	agent	1 dissented
#
# 	patient	1 did
#
#
# 704 4 Stallworth he/him/his
#
#
# 	agent	1 noted
#
# 	patient	1 doing
#
#
# 709 4 Dyson he/him/his
#
# 	poss	1 definition
#
# 	agent	1 wrote
#
#
# 	mod	1 figure
#
# 723 4 Morgan he/him/his
#
#
# 	agent	1 found
# 	agent	1 left
#
#
#
# 729 4 Andrew Maynard he/him/his
#
#
# 	agent	1 talked
# 	agent	1 put
# 	agent	1 moved
#
#
#
# 767 4 Americans they/them/their
#
# 	poss	1 leaders
#
# 	agent	1 allowed
# 	agent	1 eaten
#
#
#
# 804 4 Lertzman he/him/his
#
#
# 	agent	1 notes
# 	agent	1 argues
# 	agent	1 refers
#
#
#
# 838 4 Foster he/him/his
#
#
# 	agent	2 recommends
# 	agent	1 wrote
# 	agent	1 notes
#
#
#
# 909 4 Scott Cassel he/him/his
#
# 	poss	1 honesty
# 	poss	1 grateful
# 	poss	1 industry
#
# 	agent	1 calls
# 	agent	1 say
# 	agent	1 assumed
#
#
#
# 922 4 405 Richard Hofstadter he/him/his
#
# 	poss	1 town
#
# 	agent	1 started
# 	agent	1 arranged
# 	agent	1 ended
#
#
#
# 965 4 Moses he/him/his
#
#
# 	agent	1 cut
# 	agent	1 done
#
# 	patient	1 stopped
#
#
# 441 3 Dr. Herbert Needleman he/him/his
#
# 	poss	1 work
#
#
#
#
# 464 3 John Ehrenfeld they/them/their
#
#
# 	agent	1 invited
#
#
#
# 466 3 Robert Pojasek he/him/his
#
#
#
#
#
# 546 3 Nikki Roy he/him/his
#
#
# 	agent	1 working
# 	agent	1 came
#
#
#
# 555 3 TURA they/them/their
#
# 	poss	1 planning
# 	poss	1 reporting
#
#
#
#
# 580 3 Jane Mayer they/them/their
#
# 	poss	1 Money
#
# 	agent	1 notes
# 	agent	1 joined
# 	agent	1 formed
# 	agent	1 see
#
#
#
# 581 3 the Kochs they/them/their
#
# 	poss	1 wealth
#
#
# 	patient	1 joined
#
# 	mod	1 ones
#
# 607 3 Clinton he/him/his
#
# 	poss	1 Review
#
# 	agent	1 modified
# 	agent	1 remove
#
#
#
# 626 3 Justice Scalia he/him/his
#
#
# 	agent	1 found
# 	agent	1 concluded
# 	agent	1 refused
# 	agent	1 ignored
#
#
#
# 668 3 Anna she/her
#
#
# 	agent	1 writes
#
#
#
# 688 3 Markets they/them/their
#
#
# 	agent	1 provide
# 	agent	1 fall
#
#
#
# 690 3 Darwin he/him/his
#
#
#
#
#
# 711 3 Professor William Wiececk he/him/his
#
#
# 	agent	1 explains
# 	agent	1 describes
# 	agent	1 quotes
#
#
#
# 713 3 TSCA he/him/his
#
# 	poss	1 rule
#
#
#
#
# 719 3 Chrichton he/him/his
#
#
# 	agent	1 raised
#
#
#
# 734 3 Vince Caprio he/him/his
#
# 	poss	1 members.235
#
# 	agent	1 stayed
# 	agent	1 invited
# 	agent	1 entitled
# 	agent	1 shared
#
#
#
# 735 3 One he/him/his
#
# 	poss	1 similarity
#
# 	agent	1 stressed
# 	agent	1 argued
#
# 	patient	1 told
#
#
# 751 3 discussant Jo Anne Shatkin of Vireo Advisors she/her
#
#
# 	agent	1 seen
# 	agent	1 designed
# 	agent	1 advises
#
# 	patient	1 have
#
#
# 771 3 Massachusetts State Senator Pat Jehlen , who agreed to propose a bill that I wrote to do he/him/his
#
#
#
#
#
# 805 3 Michael Price he/him/his
#
#
# 	agent	1 look
# 	agent	1 act
#
#
#
# 815 3 Clinton he/him/his
#
# 	poss	1 Order
#
# 	agent	2 issued
#
#
#
# 843 3 FDR he/him/his
#
#
# 	agent	1 stated
# 	agent	1 proposed
#
# 	patient	1 recall
#
#
# 196 3 the US he/him/his
#
#
# 	agent	1 plays
#
# 	patient	1 bound
#
# 	mod	1 party
#
# 850 3 the Cherokee they/them/their
#
#
#
# 	patient	1 driven
#
#
# 851 3 President Andrew Jackson he/him/his
#
# 	poss	1 actions
#
#
#
#
# 861 3 William Cronon he/him/his
#
#
# 	agent	1 explains
# 	agent	1 contrasts
# 	agent	1 observes
#
#
#
# 864 3 the Yanomami he/him/his
#
#
#
#
#
# 867 3 Dear Rick he/him/his
#
#
#
# 	patient	1 thank
#
# 	mod	1 willing
# 	mod	1 available
#
# 873 3 OSWM he/him/his
#
#
# 	agent	1 had
#
# 	patient	1 created
# 	patient	1 transformed
#
#
# 876 3 George H.W. Bush he/him/his
#
#
# 	agent	1 competing
# 	agent	1 pointed
# 	agent	1 talked
#
#
#
# 884 3 ERP he/him/his
#
#
# 	agent	1 said
#
#
#
# 885 3 NBEN they/them/their
#
# 	poss	1 issues
#
#
#
# 	mod	1 entity
# 	mod	1 group
#
# 920 3 Lester Ward he/him/his
#
# 	poss	1 time
#
# 	agent	1 wrote
#
#
# 	mod	1 founder
#
# 924 3 Gerry Braun he/him/his
#
# 	poss	1 perspective
#
# 	agent	1 notes
# 	agent	1 argues
#
#
#
# 936 3 the Ecologist Simon Fairlie he/him/his
#
#
# 	agent	1 writes
# 	agent	1 describes
#
#
#
# 960 3 Joseph Lstiburek he/him/his
#
#
# 	agent	1 came
# 	agent	1 gave
# 	agent	1 made
# 	agent	1 involves
#
# 	patient	1 found
#
#
# 964 3 Robert Caro he/him/his
#
# 	poss	1 parkways
#
# 	agent	1 limited
#
#
#
# 454 2 Commissioner Jim Gutensohn he/him/his
#
#
#
#
#
# 463 2 Nick Ashford they/them/their
#
#
# 	agent	1 chaired
#
#
#
# 465 2 Jennifer Nash they/them/their
#
#
# 	agent	1 invited
#
#
#
# 467 2 Robert Capaccio he/him/his
#
#
#
#
#
# 481 2 E.O. Wilson they/them/their
#
#
# 	agent	1 recommended
#
#
#
# 488 2 Salman Sakir he/him/his
#
#
# 	agent	1 recommends
#
#
#
# 495 2 Stephanie Brody he/him/his
#
#
# 	agent	2 writes
#
#
#
# 501 2 Thomas Jefferson he/him/his
#
#
# 	agent	1 find
#
#
# 	mod	1 owner
#
# 502 2 Nicholas Kristov he/him/his
#
#
# 	agent	1 talked
# 	agent	1 knew
#
#
#
# 505 2 Environmentalists they/them/their
#
#
# 	agent	1 prefer
# 	agent	1 remember
#
#
#
# 510 2 The Nez Perce he/him/his
#
#
#
#
# 	mod	1 alone
#
# 513 2 49 Perry Gottesfeld he/him/his
#
#
# 	agent	1 notes
#
# 	patient	1 take
#
#
# 517 2 Kim he/him/his
#
#
#
#
#
# 530 2 Churchill they/them/their
#
#
#
#
#
# 543 2 Bill Napolitano they/them/their
#
#
# 	agent	1 tell
#
#
#
# 544 2 Lee Dane he/him/his
#
# 	poss	1 joke
#
# 	agent	1 took
#
#
#
# 549 2 Gina McCarthy she/her
#
#
#
#
# 	mod	1 coordinator
#
# 550 2 Joe Paluzzi he/him/his
#
# 	poss	1 belief
#
# 	agent	1 aided
#
#
#
# 551 2 Mitch Kennedy he/him/his
#
#
# 	agent	1 aided
#
#
#
# 563 2 111 Gary Miller he/him/his
#
#
# 	agent	1 worked
#
#
#
# 564 2 Jeffrey Burke he/him/his
#
#
#
#
# 	mod	1 director
#
# 568 2 P2 he/him/his
#
# 	poss	1 brother
#
#
#
#
# 577 2 Powell he/him/his
#
#
#
#
#
# 579 2 Nancy MacLean he/him/his
#
# 	poss	2 Democracy
#
#
#
#
# 586 2 John C. Calhoun they/them/their
#
#
# 	agent	1 found
#
#
#
# 590 2 Mitch McConnell he/him/his
#
# 	poss	1 predicament
#
#
#
#
# 605 2 Senator Sheldon Whitehouse he/him/his
#
#
# 	agent	1 delivered
# 	agent	1 intended
#
#
#
# 620 2 Norman Ornstein he/him/his
#
#
# 	agent	1 said
#
#
#
# 622 2 David Rosner he/him/his
#
#
#
#
#
# 623 2 Gerald Markowitz she/her
#
#
#
#
#
# 629 2 Tom Hayden he/him/his
#
#
# 	agent	1 approve
#
#
#
# 630 2 John Dewey he/him/his
#
#
#
#
#
# 637 2 Cardinal Joseph Ratzinger he/him/his
#
#
# 	agent	1 did
# 	agent	1 became
#
#
#
# 640 2 Kant he/him/his
#
#
# 	agent	1 tried
#
#
#
# 641 2 Bertrand Russel he/him/his
#
#
# 	agent	1 tried
#
#
#
# 642 2 David Copp they/them/their
#
#
# 	agent	1 proposes
# 	agent	1 argues
#
#
#
# 643 2 Chris Gowans he/him/his
#
#
# 	agent	1 writes
#
#
#
# 649 2 the People he/him/his
#
#
#
# 	patient	1 acknowledge
#
#
# 654 2 Buckminster Fuller he/him/his
#
#
# 	agent	1 invented
#
#
#
# 658 2 Grear he/him/his
#
#
#
# 	patient	1 agree
#
#
# 680 2 Vaclav Klaus he/him/his
#
#
# 	agent	1 warned
#
#
# 	mod	1 president
#
# 692 2 Mr. Herbert Spencer he/him/his
#
# 	poss	1 Statics
#
#
#
#
# 699 2 Adam Finkel he/him/his
#
#
# 	agent	1 hosted
# 	agent	1 pointed
#
#
#
# 707 2 ALARA they/them/their
#
#
#
# 	patient	1 apply
# 	patient	1 required
#
#
# 736 2 Laurie Burt she/her
#
#
#
#
#
# 739 2 Greylin Neilson she/her
#
#
# 	agent	1 found
#
#
#
# 743 2 Vicki Colvin she/her
#
#
# 	agent	1 talked
# 	agent	1 said
# 	agent	1 made
#
#
#
# 744 2 Dave Rejeski he/him/his
#
#
# 	agent	1 worked
# 	agent	1 stopped
#
#
#
# 748 2 Pirela he/him/his
#
# 	poss	1 findings
#
#
#
#
# 755 2 BPS they/them/their
#
#
#
#
# 	mod	1 child
#
# 765 2 William Ruckelshaus he/him/his
#
#
#
#
# 	mod	1 right
#
# 768 2 Uncle Joe he/him/his
#
#
# 	agent	1 says
# 	agent	1 painted
# 	agent	1 work
#
#
#
# 776 2 Kai Medina he/him/his
#
#
# 	agent	1 made
#
#
# 	mod	1 student
#
# 799 2 Anne Aiken he/him/his
#
#
#
#
#
# 801 2 Harold Searles he/him/his
#
# 	poss	1 work
#
# 	agent	1 wrote
#
#
#
# 806 2 Sally Weintrobe he/him/his
#
#
#
#
#
# 807 2 Robert Stolorow he/him/his
#
#
# 	agent	1 advises
#
#
#
# 813 2 Delmore Schwartz he/him/his
#
#
# 	agent	1 wrote
# 	agent	1 took
#
#
#
# 816 2 Northeastern Professors Daniel Faber he/him/his
#
#
# 	agent	1 based
#
#
#
# 817 2 Eric Krieg he/him/his
#
#
# 	agent	1 based
#
#
#
# 822 2 Katie Walker he/him/his
#
#
#
#
#
# 829 2 Aseel Alharthi he/him/his
#
#
# 	agent	1 developed
#
#
#
# 832 2 Cory Booker he/him/his
#
#
# 	agent	2 proposed
#
#
#
# 859 2 Robin Kimmerer they/them/their
#
#
# 	agent	1 calls
# 	agent	1 https://www.esf.edu/faculty/kimmerer/
#
#
#
# 869 2 Zoom he/him/his
#
#
#
#
#
# 888 2 Marina Gayl she/her
#
#
# 	agent	1 organized
# 	agent	1 retired
#
#
#
# 891 2 Hands he/him/his
#
#
# 	agent	2 shot
# 	agent	1 asked
# 	agent	1 started
#
#
#
# 897 2 Amy Kyle she/her
#
#
# 	agent	1 said
# 	agent	1 thought
#
#
#
# 899 2 An SEP he/him/his
#
#
# 	agent	1 do
#
#
#
# 910 2 Chris Beling he/him/his
#
# 	poss	1 presentation
#
# 	agent	1 continued
#
#
#
# 915 2 Thomas Ricks he/him/his
#
#
#
# 	patient	1 put
# 	patient	1 set
#
#
# 942 2 Jedidiah Purdy of Duke Law School he/him/his
#
#
# 	agent	1 uses
# 	agent	1 cites
#
#
#
# 944 2 Wenona Hauter he/him/his
#
#
# 	agent	1 points
#
#
#
# 963 2 Tom Angotti he/him/his
#
#
# 	agent	1 asks
# 	agent	1 notes
#
#
#
# 970 2 Nikita Krushchev he/him/his
#
#
# 	agent	1 want
# 	agent	1 got
#
#
#
# 971 2 Roger Cobb they/them/their
#
#
#
#
#
# 978 2 Hans Bethe he/him/his
#
#
#
#
#
# 993 2 Paul Kix he/him/his
#
#
# 	agent	1 wrote
#
#
#
# 1011 2 David Bollier he/him/his

# %% [markdown]
# # New Section
